# %%
# !pip install -q transformers accelerate safetensors scikit-learn

# %%
import torch
import numpy as np
import pandas as pd
import os
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')

# Verify the folder is visible
# !ls /content/drive/MyDrive/hinemo
# Out:
# Mounted at /content/drive
# checkpoints  DATASET_FOR_HINEMO  hidden_states	splits

# %%
# ── CHANGE ONLY THESE TWO LINES per Colab account ──────────────
#HF_MODEL_ID  = "bert-base-multilingual-cased"  # HuggingFace model ID
#MODEL_FOLDER = "bert-base-multilingual-cased"  # folder name inside checkpoints/

# For MuRIL:
HF_MODEL_ID  = "google/muril-base-cased"
MODEL_FOLDER = "muril-base-cased"

# For XLM-R:
# HF_MODEL_ID  = "xlm-roberta-base"
# MODEL_FOLDER = "xlm-roberta-base"

# Paths — all derived from the two lines above
BASE_DIR       = "/content/drive/MyDrive/hinemo"
VAL_PATH       = f"{BASE_DIR}/splits/hinemo_val.csv"
CHECKPOINT_DIR = f"{BASE_DIR}/checkpoints/{MODEL_FOLDER}/best_model"
OUTPUT_DIR     = f"{BASE_DIR}/hidden_states/{MODEL_FOLDER}"

# Constants — never change these
BATCH_SIZE        = 32
MAX_LENGTH        = 128
RANDOM_SEED       = 524
SAMPLES_PER_CLASS = 750   # 750 × 4 emotions = 3,000 total

print(f"Model:       {HF_MODEL_ID}")
print(f"Checkpoint:  {CHECKPOINT_DIR}")
print(f"Output:      {OUTPUT_DIR}")
# Out:
# Model:       google/muril-base-cased
# Checkpoint:  /content/drive/MyDrive/hinemo/checkpoints/muril-base-cased/best_model
# Output:      /content/drive/MyDrive/hinemo/hidden_states/muril-base-cased

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

if device.type == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: No GPU detected. Go to Runtime > Change runtime type > T4 GPU")
# Out:
# Device: cuda
# GPU: Tesla T4

# %%
# Load full val set
val_df = pd.read_csv(VAL_PATH)
print(f"Full val set: {len(val_df)} rows")
print(val_df["gpt_emotion"].value_counts())

# Stratified subsample: 750 per class
sample_df = (
    val_df
    .groupby("gpt_emotion", group_keys=False)
    .apply(lambda x: x.sample(SAMPLES_PER_CLASS, random_state=RANDOM_SEED))
    .reset_index(drop=True)
)

print(f"\nSubsample: {len(sample_df)} rows")
print(sample_df["gpt_emotion"].value_counts())

# Create output directory and save metadata
os.makedirs(OUTPUT_DIR, exist_ok=True)

metadata = sample_df[["id", "gpt_emotion", "lambda"]].reset_index(drop=True)
metadata.to_csv(f"{OUTPUT_DIR}/metadata.csv", index=False)
print(f"\nMetadata saved to {OUTPUT_DIR}/metadata.csv")
# Out:
# Full val set: 6926 rows
# gpt_emotion
# joy        2658
# anger      1855
# disgust    1304
# sadness    1109
# Name: count, dtype: int64
#
# Subsample: 3000 rows
# gpt_emotion
# anger      750
# disgust    750
# joy        750
# sadness    750
# Name: count, dtype: int64
#
# Metadata saved to /content/drive/MyDrive/hinemo/hidden_states/muril-base-cased/metadata.csv
# /tmp/ipykernel_664/1244759081.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(SAMPLES_PER_CLASS, random_state=RANDOM_SEED))

# %%
def extract_hidden_states(model_path, sample_df, tokenizer, label):
    print(f"\nLoading model from: {model_path}")

    model = AutoModelForSequenceClassification.from_pretrained(
        model_path,
        output_hidden_states=True,
        ignore_mismatched_sizes=True   # suppresses warning for pretrained (no classification head yet)
    ).to(device).eval()

    all_hidden = []

    for i in tqdm(range(0, len(sample_df), BATCH_SIZE), desc=f"Extracting [{label}]"):
        batch_texts = sample_df["text"].iloc[i : i + BATCH_SIZE].tolist()

        encoded = tokenizer(
            batch_texts,
            max_length=MAX_LENGTH,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        ).to(device)

        with torch.no_grad():
            outputs = model(**encoded)

        # hidden_states: tuple of 13 tensors, each (batch, seq_len, 768)
        # Skip index 0 (embedding layer), take layers 1-12
        # [:, 0, :] = CLS token only
        cls_per_layer = torch.stack(
            [h[:, 0, :] for h in outputs.hidden_states[1:]],
            dim=1
        )  # shape: (batch_size, 12, 768)

        all_hidden.append(cls_per_layer.cpu().numpy())

    # Stack all batches → (3000, 12, 768)
    hidden_array = np.concatenate(all_hidden, axis=0)

    # Save to Drive
    save_path = f"{OUTPUT_DIR}/hidden_{label}.npy"
    np.save(save_path, hidden_array)
    print(f"Saved: {save_path}  |  Shape: {hidden_array.shape}")

    # Free GPU memory before next run
    del model
    torch.cuda.empty_cache()

    return hidden_array

# %%
tokenizer = AutoTokenizer.from_pretrained(HF_MODEL_ID)
print(f"Tokenizer loaded: {HF_MODEL_ID}")
# Out:
# config.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/206 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/113 [00:00<?, ?B/s]
# Tokenizer loaded: google/muril-base-cased

# %%
hidden_pretrained = extract_hidden_states(
    model_path = HF_MODEL_ID,
    sample_df  = sample_df,
    tokenizer  = tokenizer,
    label      = "pretrained"
)
# Out:
# Loading model from: google/muril-base-cased
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  953MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: google/muril-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  953MB
# model.safetensors: downloading bytes:           |  0.00B
# Extracting [pretrained]:   0%|          | 0/94 [00:00<?, ?it/s]
#
# Extracting [pretrained]:   1%|          | 1/94 [00:00<01:27,  1.06it/s]
#
# Extracting [pretrained]:   2%|▏         | 2/94 [00:01<00:45,  2.01it/s]
#
# Extracting [pretrained]:   3%|▎         | 3/94 [00:01<00:32,  2.80it/s]
#
# Extracting [pretrained]:   4%|▍         | 4/94 [00:01<00:26,  3.43it/s]
#
# Extracting [pretrained]:   5%|▌         | 5/94 [00:01<00:23,  3.77it/s]
#
# Extracting [pretrained]:   6%|▋         | 6/94 [00:01<00:21,  4.07it/s]
#
# Extracting [pretrained]:   7%|▋         | 7/94 [00:02<00:19,  4.37it/s]
#
# Extracting [pretrained]:   9%|▊         | 8/94 [00:02<00:18,  4.62it/s]
#
# Extracting [pretrained]:  10%|▉         | 9/94 [00:02<00:18,  4.62it/s]
#
# Extracting [pretrained]:  11%|█         | 10/94 [00:02<00:17,  4.75it/s]
#
# Extracting [pretrained]:  12%|█▏        | 11/94 [00:02<00:17,  4.61it/s]
#
# Extracting [pretrained]:  13%|█▎        | 12/94 [00:03<00:17,  4.72it/s]
#
# Extracting [pretrained]:  14%|█▍        | 13/94 [00:03<00:17,  4.69it/s]
#
# Extracting [pretrained]:  15%|█▍        | 14/94 [00:03<00:17,  4.65it/s]
#
# Extracting [pretrained]:  16%|█▌        | 15/94 [00:03<00:16,  4.70it/s]
#
# Extracting [pretrained]:  17%|█▋        | 16/94 [00:04<00:16,  4.66it/s]
#
# Extracting [pretrained]:  18%|█▊        | 17/94 [00:04<00:16,  4.56it/s]
#
# Extracting [pretrained]:  19%|█▉        | 18/94 [00:04<00:16,  4.52it/s]
#
# Extracting [pretrained]:  20%|██        | 19/94 [00:04<00:16,  4.54it/s]
#
# Extracting [pretrained]:  21%|██▏       | 20/94 [00:04<00:16,  4.57it/s]
#
# Extracting [pretrained]:  22%|██▏       | 21/94 [00:05<00:15,  4.59it/s]
#
# Extracting [pretrained]:  23%|██▎       | 22/94 [00:05<00:15,  4.62it/s]
#
# Extracting [pretrained]:  24%|██▍       | 23/94 [00:05<00:15,  4.56it/s]
#
# Extracting [pretrained]:  26%|██▌       | 24/94 [00:05<00:16,  4.29it/s]
#
# Extracting [pretrained]:  27%|██▋       | 25/94 [00:06<00:15,  4.38it/s]
#
# Extracting [pretrained]:  28%|██▊       | 26/94 [00:06<00:15,  4.40it/s]
#
# Extracting [pretrained]:  29%|██▊       | 27/94 [00:06<00:15,  4.44it/s]
#
# Extracting [pretrained]:  30%|██▉       | 28/94 [00:06<00:14,  4.43it/s]
#
# Extracting [pretrained]:  31%|███       | 29/94 [00:06<00:14,  4.35it/s]
#
# Extracting [pretrained]:  32%|███▏      | 30/94 [00:07<00:14,  4.49it/s]
#
# Extracting [pretrained]:  33%|███▎      | 31/94 [00:07<00:14,  4.47it/s]
#
# Extracting [pretrained]:  34%|███▍      | 32/94 [00:07<00:13,  4.63it/s]
#
# Extracting [pretrained]:  35%|███▌      | 33/94 [00:07<00:12,  4.70it/s]
#
# Extracting [pretrained]:  36%|███▌      | 34/94 [00:08<00:12,  4.75it/s]
#
# Extracting [pretrained]:  37%|███▋      | 35/94 [00:08<00:12,  4.80it/s]
#
# Extracting [pretrained]:  38%|███▊      | 36/94 [00:08<00:11,  4.85it/s]
#
# Extracting [pretrained]:  39%|███▉      | 37/94 [00:08<00:11,  4.85it/s]
#
# Extracting [pretrained]:  40%|████      | 38/94 [00:08<00:11,  4.87it/s]
#
# Extracting [pretrained]:  41%|████▏     | 39/94 [00:09<00:11,  4.92it/s]
#
# Extracting [pretrained]:  43%|████▎     | 40/94 [00:09<00:10,  4.94it/s]
#
# Extracting [pretrained]:  44%|████▎     | 41/94 [00:09<00:10,  4.96it/s]
#
# Extracting [pretrained]:  45%|████▍     | 42/94 [00:09<00:10,  4.88it/s]
#
# Extracting [pretrained]:  46%|████▌     | 43/94 [00:09<00:11,  4.47it/s]
#
# Extracting [pretrained]:  47%|████▋     | 44/94 [00:10<00:10,  4.60it/s]
#
# Extracting [pretrained]:  48%|████▊     | 45/94 [00:10<00:10,  4.70it/s]
#
# Extracting [pretrained]:  49%|████▉     | 46/94 [00:10<00:10,  4.80it/s]
#
# Extracting [pretrained]:  50%|█████     | 47/94 [00:10<00:09,  4.85it/s]
#
# Extracting [pretrained]:  51%|█████     | 48/94 [00:10<00:09,  4.91it/s]
#
# Extracting [pretrained]:  52%|█████▏    | 49/94 [00:11<00:09,  4.93it/s]
#
# Extracting [pretrained]:  53%|█████▎    | 50/94 [00:11<00:08,  4.97it/s]
#
# Extracting [pretrained]:  54%|█████▍    | 51/94 [00:11<00:08,  5.00it/s]
#
# Extracting [pretrained]:  55%|█████▌    | 52/94 [00:11<00:08,  5.00it/s]
#
# Extracting [pretrained]:  56%|█████▋    | 53/94 [00:11<00:08,  4.99it/s]
#
# Extracting [pretrained]:  57%|█████▋    | 54/94 [00:12<00:08,  4.98it/s]
#
# Extracting [pretrained]:  59%|█████▊    | 55/94 [00:12<00:07,  5.02it/s]
#
# Extracting [pretrained]:  60%|█████▉    | 56/94 [00:12<00:07,  5.06it/s]
#
# Extracting [pretrained]:  61%|██████    | 57/94 [00:12<00:07,  5.08it/s]
#
# Extracting [pretrained]:  62%|██████▏   | 58/94 [00:12<00:07,  5.09it/s]
#
# Extracting [pretrained]:  63%|██████▎   | 59/94 [00:13<00:06,  5.07it/s]
#
# Extracting [pretrained]:  64%|██████▍   | 60/94 [00:13<00:06,  5.09it/s]
#
# Extracting [pretrained]:  65%|██████▍   | 61/94 [00:13<00:06,  5.09it/s]
#
# Extracting [pretrained]:  66%|██████▌   | 62/94 [00:13<00:06,  5.09it/s]
#
# Extracting [pretrained]:  67%|██████▋   | 63/94 [00:13<00:06,  5.08it/s]
#
# Extracting [pretrained]:  68%|██████▊   | 64/94 [00:14<00:05,  5.10it/s]
#
# Extracting [pretrained]:  69%|██████▉   | 65/94 [00:14<00:05,  5.10it/s]
#
# Extracting [pretrained]:  70%|███████   | 66/94 [00:14<00:05,  5.10it/s]
#
# Extracting [pretrained]:  71%|███████▏  | 67/94 [00:14<00:05,  5.10it/s]
#
# Extracting [pretrained]:  72%|███████▏  | 68/94 [00:14<00:05,  5.07it/s]
#
# Extracting [pretrained]:  73%|███████▎  | 69/94 [00:15<00:04,  5.08it/s]
#
# Extracting [pretrained]:  74%|███████▍  | 70/94 [00:15<00:04,  5.08it/s]
#
# Extracting [pretrained]:  76%|███████▌  | 71/94 [00:15<00:04,  5.10it/s]
#
# Extracting [pretrained]:  77%|███████▋  | 72/94 [00:15<00:04,  5.11it/s]
#
# Extracting [pretrained]:  78%|███████▊  | 73/94 [00:15<00:04,  5.08it/s]
#
# Extracting [pretrained]:  79%|███████▊  | 74/94 [00:16<00:03,  5.08it/s]
#
# Extracting [pretrained]:  80%|███████▉  | 75/94 [00:16<00:03,  5.09it/s]
#
# Extracting [pretrained]:  81%|████████  | 76/94 [00:16<00:03,  5.09it/s]
#
# Extracting [pretrained]:  82%|████████▏ | 77/94 [00:16<00:03,  5.07it/s]
#
# Extracting [pretrained]:  83%|████████▎ | 78/94 [00:16<00:03,  5.08it/s]
#
# Extracting [pretrained]:  84%|████████▍ | 79/94 [00:17<00:02,  5.08it/s]
#
# Extracting [pretrained]:  85%|████████▌ | 80/94 [00:17<00:02,  5.05it/s]
#
# Extracting [pretrained]:  86%|████████▌ | 81/94 [00:17<00:02,  5.05it/s]
#
# Extracting [pretrained]:  87%|████████▋ | 82/94 [00:17<00:02,  5.05it/s]
#
# Extracting [pretrained]:  88%|████████▊ | 83/94 [00:17<00:02,  5.03it/s]
#
# Extracting [pretrained]:  89%|████████▉ | 84/94 [00:18<00:01,  5.03it/s]
#
# Extracting [pretrained]:  90%|█████████ | 85/94 [00:18<00:01,  5.01it/s]
#
# Extracting [pretrained]:  91%|█████████▏| 86/94 [00:18<00:01,  5.03it/s]
#
# Extracting [pretrained]:  93%|█████████▎| 87/94 [00:18<00:01,  5.04it/s]
#
# Extracting [pretrained]:  94%|█████████▎| 88/94 [00:18<00:01,  5.04it/s]
#
# Extracting [pretrained]:  95%|█████████▍| 89/94 [00:18<00:00,  5.03it/s]
#
# Extracting [pretrained]:  96%|█████████▌| 90/94 [00:19<00:00,  5.04it/s]
#
# Extracting [pretrained]:  97%|█████████▋| 91/94 [00:19<00:00,  5.03it/s]
#
# Extracting [pretrained]:  98%|█████████▊| 92/94 [00:19<00:00,  5.04it/s]
#
# Extracting [pretrained]:  99%|█████████▉| 93/94 [00:19<00:00,  5.05it/s]
#
# Extracting [pretrained]: 100%|██████████| 94/94 [00:19<00:00,  4.71it/s]
# Saved: /content/drive/MyDrive/hinemo/hidden_states/muril-base-cased/hidden_pretrained.npy  |  Shape: (3000, 12, 768)

# %%
hidden_finetuned = extract_hidden_states(
    model_path = CHECKPOINT_DIR,
    sample_df  = sample_df,
    tokenizer  = tokenizer,
    label      = "finetuned"
)
# Out:
# Loading model from: /content/drive/MyDrive/hinemo/checkpoints/muril-base-cased/best_model
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Extracting [finetuned]: 100%|██████████| 94/94 [00:21<00:00,  4.42it/s]
# Saved: /content/drive/MyDrive/hinemo/hidden_states/muril-base-cased/hidden_finetuned.npy  |  Shape: (3000, 12, 768)

# %%
# Reload from Drive and verify shapes
h_pre  = np.load(f"{OUTPUT_DIR}/hidden_pretrained.npy")
h_fine = np.load(f"{OUTPUT_DIR}/hidden_finetuned.npy")
meta   = pd.read_csv(f"{OUTPUT_DIR}/metadata.csv")

print(f"Pretrained shape:  {h_pre.shape}   ← should be (3000, 12, 768)")
print(f"Finetuned shape:   {h_fine.shape}  ← should be (3000, 12, 768)")
print(f"Metadata rows:     {len(meta)}      ← should be 3000")
print(f"\nEmotion distribution in subsample:")
print(meta["gpt_emotion"].value_counts())
# Out:
# Pretrained shape:  (3000, 12, 768)   ← should be (3000, 12, 768)
# Finetuned shape:   (3000, 12, 768)  ← should be (3000, 12, 768)
# Metadata rows:     3000      ← should be 3000
#
# Emotion distribution in subsample:
# gpt_emotion
# anger      750
# disgust    750
# joy        750
# sadness    750
# Name: count, dtype: int64
