# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from itertools import combinations
import json
import os

# %%
# ── CHANGE THESE TWO LINES per run ──────────────────────────────
MODEL_FOLDER = "xlm-roberta-base" # "bert-base-multilingual-cased" or "muril-base-cased" or "xlm-roberta-base"
STATE        = "pretrained" # "pretrained" or "finetuned"
# ────────────────────────────────────────────────────────────────

BASE_DIR   = "/Users/harshaggarwal/Projects_4/hinemo_project/models/hidden_states"
MODEL_DIR  = f"{BASE_DIR}/{MODEL_FOLDER}"
OUTPUT_DIR = f"/Users/harshaggarwal/Projects_4/hinemo_project/models/probing_results/{MODEL_FOLDER}"

os.makedirs(OUTPUT_DIR, exist_ok=True)

EMOTIONS = ["anger", "disgust", "joy", "sadness"]

print(f"Model:  {MODEL_FOLDER}")
print(f"State:  {STATE}")
# Out:
# Model:  xlm-roberta-base
# State:  pretrained

# %%
hidden      = np.load(f"{MODEL_DIR}/hidden_{STATE}.npy")
meta        = pd.read_csv(f"{MODEL_DIR}/metadata.csv")
lambda_vals = meta["lambda"].values

n_samples, n_layers, hidden_dim = hidden.shape

print(f"Hidden states: {hidden.shape}")
print(f"\nSamples per emotion:")
print(meta["gpt_emotion"].value_counts())
# Out:
# Hidden states: (3000, 12, 768)
#
# Samples per emotion:
# gpt_emotion
# anger      750
# disgust    750
# joy        750
# sadness    750
# Name: count, dtype: int64

# %%
r2_per_emotion = {}   # stores full R² curve per emotion
lsl_per_emotion = {}  # stores peak layer per emotion

for emotion in EMOTIONS:
    mask        = meta["gpt_emotion"] == emotion
    X_emotion   = hidden[mask]          # shape: (~750, 12, 768)
    y_emotion   = lambda_vals[mask]     # shape: (~750,)

    print(f"\n── {emotion.upper()} ({mask.sum()} samples) ──")

    r2_curve = []
    for layer in range(n_layers):
        X      = X_emotion[:, layer, :]
        probe  = Ridge(alpha=1.0)
        scores = cross_val_score(probe, X, y_emotion, cv=5, scoring="r2")
        r2_curve.append(scores.mean())
        print(f"  Layer {layer+1:2d}: R² = {scores.mean():.4f}")

    lsl_e = int(np.argmax(r2_curve)) + 1
    r2_per_emotion[emotion]  = r2_curve
    lsl_per_emotion[emotion] = lsl_e

    print(f"  LSL({emotion}) = Layer {lsl_e}  |  Peak R² = {max(r2_curve):.4f}")
# Out:
# ── ANGER (750 samples) ──
#   Layer  1: R² = 0.4903
#   Layer  2: R² = 0.3974
#   Layer  3: R² = 0.2952
#   Layer  4: R² = 0.1381
#   Layer  5: R² = 0.3790
#   Layer  6: R² = 0.0696
#   Layer  7: R² = -0.0048
#   Layer  8: R² = 0.0321
#   Layer  9: R² = 0.0624
#   Layer 10: R² = 0.1860
#   Layer 11: R² = 0.4140
#   Layer 12: R² = 0.6140
#   LSL(anger) = Layer 12  |  Peak R² = 0.6140
#
# ── DISGUST (750 samples) ──
#   Layer  1: R² = 0.4885
#   Layer  2: R² = 0.4297
#   Layer  3: R² = 0.2859
#   Layer  4: R² = 0.1480
#   Layer  5: R² = 0.3737
#   Layer  6: R² = 0.0605
#   Layer  7: R² = -0.0013
#   Layer  8: R² = 0.0304
#   Layer  9: R² = 0.0526
#   Layer 10: R² = 0.1782
#   Layer 11: R² = 0.4419
#   Layer 12: R² = 0.6057
#   LSL(disgust) = Layer 12  |  Peak R² = 0.6057
#
# ── JOY (750 samples) ──
#   Layer  1: R² = 0.6318
#   Layer  2: R² = 0.5659
#   Layer  3: R² = 0.4438
#   Layer  4: R² = 0.2625
#   Layer  5: R² = 0.4838
#   Layer  6: R² = 0.0996
#   Layer  7: R² = -0.0015
#   Layer  8: R² = 0.0630
#   Layer  9: R² = 0.0811
#   Layer 10: R² = 0.2542
#   Layer 11: R² = 0.5754
#   Layer 12: R² = 0.6676
#   LSL(joy) = Layer 12  |  Peak R² = 0.6676
#
# ── SADNESS (750 samples) ──
#   Layer  1: R² = 0.6470
#   Layer  2: R² = 0.5491
#   Layer  3: R² = 0.4522
#   Layer  4: R² = 0.2899
#   Layer  5: R² = 0.5226
#   Layer  6: R² = 0.1127
#   Layer  7: R² = -0.0071
#   Layer  8: R² = 0.0752
#   Layer  9: R² = 0.0744
#   Layer 10: R² = 0.2657
#   Layer 11: R² = 0.5973
#   Layer 12: R² = 0.7432
#   LSL(sadness) = Layer 12  |  Peak R² = 0.7432

# %%
print("\n── EMOTION LSL SUMMARY ──")
print(f"{'Emotion':<10} {'LSL':<6} {'Peak R²'}")
print("-" * 30)

for emotion in EMOTIONS:
    lsl  = lsl_per_emotion[emotion]
    peak = max(r2_per_emotion[emotion])
    print(f"{emotion:<10} {lsl:<6} {peak:.4f}")
# Out:
# ── EMOTION LSL SUMMARY ──
# Emotion    LSL    Peak R²
# ------------------------------
# anger      12     0.6140
# disgust    12     0.6057
# joy        12     0.6676
# sadness    12     0.7432

# %%
pairs         = list(combinations(EMOTIONS, 2))
pairwise_diffs = [abs(lsl_per_emotion[e1] - lsl_per_emotion[e2]) for e1, e2 in pairs]
ELDS          = sum(pairwise_diffs) / len(pairwise_diffs)

print("── PAIRWISE LSL DIFFERENCES ──")
for (e1, e2), diff in zip(pairs, pairwise_diffs):
    print(f"  |LSL({e1}) - LSL({e2})| = {diff}")

print(f"\nELDS = {ELDS:.4f}")
# Out:
# ── PAIRWISE LSL DIFFERENCES ──
#   |LSL(anger) - LSL(disgust)| = 0
#   |LSL(anger) - LSL(joy)| = 0
#   |LSL(anger) - LSL(sadness)| = 0
#   |LSL(disgust) - LSL(joy)| = 0
#   |LSL(disgust) - LSL(sadness)| = 0
#   |LSL(joy) - LSL(sadness)| = 0
#
# ELDS = 0.0000

# %%
results = {
    "model"           : MODEL_FOLDER,
    "state"           : STATE,
    "lsl_per_emotion" : lsl_per_emotion,
    "r2_per_emotion"  : r2_per_emotion,
    "ELDS"            : ELDS,
    "pairwise_diffs"  : {f"{e1}_vs_{e2}": abs(lsl_per_emotion[e1] - lsl_per_emotion[e2]) 
                         for e1, e2 in pairs}
}

save_path = f"{OUTPUT_DIR}/emotion_probing_{STATE}.json"
with open(save_path, "w") as f:
    json.dump(results, f, indent=2)

print(f"Saved to {save_path}")
# Out:
# Saved to /Users/harshaggarwal/Projects_4/hinemo_project/models/probing_results/xlm-roberta-base/emotion_probing_pretrained.json

# %%
n_permutations  = 1000
permuted_elds   = []

for perm in range(n_permutations):
    # Shuffle emotion labels randomly
    shuffled = meta["gpt_emotion"].sample(frac=1, random_state=perm).values

    perm_lsl = {}
    for emotion in EMOTIONS:
        mask    = shuffled == emotion
        X_perm  = hidden[mask]
        y_perm  = lambda_vals[mask]

        r2s = []
        for layer in range(n_layers):
            X      = X_perm[:, layer, :]
            probe  = Ridge(alpha=1.0)
            scores = cross_val_score(probe, X, y_perm, cv=5, scoring="r2")
            r2s.append(scores.mean())

        perm_lsl[emotion] = int(np.argmax(r2s)) + 1

    diffs = [abs(perm_lsl[e1] - perm_lsl[e2]) for e1, e2 in pairs]
    permuted_elds.append(sum(diffs) / len(diffs))

    if (perm + 1) % 100 == 0:
        print(f"  {perm+1}/1000 done...")

permuted_array = np.array(permuted_elds)
p_value        = (permuted_array >= ELDS).mean()

print(f"\nReal ELDS:        {ELDS:.4f}")
print(f"Mean permuted:    {permuted_array.mean():.4f}")
print(f"p-value:          {p_value:.4f}")
print(f"Significant p<0.05: {p_value < 0.05}")
# Out:
#   100/1000 done...
#   200/1000 done...
#   300/1000 done...
#   400/1000 done...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 18
#      14         r2s = []
#      15         for layer in range(n_layers):
#      16             X      = X_perm[:, layer, :]
#      17             probe  = Ridge(alpha=1.0)
# ---> 18             scores = cross_val_score(probe, X, y_perm, cv=5, scoring="r2")
#      19             r2s.append(scores.mean())
#      20
#      21         perm_lsl[emotion] = int(np.argmax(r2s)) + 1
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:650, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     647 # To ensure multimetric format is not supported
#     648 scorer = check_scoring(estimator, scoring=scoring)
# --> 650 cv_results = cross_validate(
#     651     estimator=estimator,
#     652     X=X,
#     653     y=y,
#     654     groups=groups,
#     655     scoring={"score": scorer},
#     656     cv=cv,
#     657     n_jobs=n_jobs,
#     658     verbose=verbose,
#     659     params=params,
#     660     pre_dispatch=pre_dispatch,
#     661     error_score=error_score,
#     662 )
#     663 return cv_results["test_score"]
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:372, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     369 # We clone the estimator to make sure that all the folds are
#     370 # independent, and that it is pickle-able.
#     371 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 372 results = parallel(
#     373     delayed(_fit_and_score)(
#     374         clone(estimator),
#     375         X,
#     376         y,
#     377         scorer=scorers,
#     378         train=train,
#     379         test=test,
#     380         verbose=verbose,
#     381         parameters=None,
#     382         fit_params=routed_params.estimator.fit,
#     383         score_params=routed_params.scorer.score,
#     384         return_train_score=return_train_score,
#     385         return_times=True,
#     386         return_estimator=return_estimator,
#     387         error_score=error_score,
#     388     )
#     389     for train, test in indices
#     390 )
#     392 _warn_or_raise_about_fit_failures(results, error_score)
#     394 # For callable scoring, the return type is only know after calling. If the
#     395 # return type is a dictionary, the error scores can now be inserted with
#     396 # the correct key.
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:832, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score, caller, callback_ctx)
#     828     estimator = estimator.set_params(**clone(parameters, safe=False))
#     830 start_time = time.time()
# --> 832 X_train, y_train = _safe_split(estimator, X, y, train)
#     833 X_test, y_test = _safe_split(estimator, X, y, test, train)
#     835 if (sample_weight := fit_params.get("sample_weight")) is not None:
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/utils/metaestimators.py:173, in _safe_split(estimator, X, y, indices, train_indices)
#     170     X_subset = _safe_indexing(X, indices)
#     172 if y is not None:
# --> 173     y_subset = _safe_indexing(y, indices)
#     174 else:
#     175     y_subset = None
#
# File ~/Projects_4/hinemo_project/.venv-hinemo/lib/python3.13/site-packages/sklearn/utils/_indexing.py:205, in _safe_indexing(X, indices, axis)
#     201                 raise ValueError(err_msg)
#     202     raise ValueError(err_msg)
# --> 205 def _safe_indexing(X, indices, *, axis=0):
#     206     """Return rows, items or columns of X using indices.
#     207
#     208     .. warning::
#    (...)    254     array([1, 3, 5])
#     255     """
#     256     if indices is None:
#
# KeyboardInterrupt:
